# %% [markdown]
# # Deep Learning in NLP

# %% [markdown]
# <center><img src="https://education-team-2020.s3.eu-west-1.amazonaws.com/ai-eng/w4-s3/deep_learning.png" width="1000"/></center>

# %% [markdown]
# ----
# Apply word2vec to a dataset
# -----
#
# Overview:
#
# 1. Download some training data
# 1. Setup word2vec model in TensorFlow
# 1. Train on the data
# 1. Visualize the result

# %%
reset -fs

# %%
# I like to live dangerously ☠
import warnings
warnings.filterwarnings('ignore')

# %%
import collections
import math
import os
from pprint import pprint
import random
import urllib.request
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf 
from sklearn.manifold import TSNE

# %matplotlib inline
# Out:
# 2024-06-12 16:35:13.704271: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ----
# Step 1: Download the data.
# ----

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(path, filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    
    if not os.path.exists(path+filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    
    statinfo = os.stat(path+filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    
    return filename

path = ""
filename = maybe_download(path, 'text8.zip', 31_344_016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# While this code ☝️  is running ⏳, preview the code ahead 🔍.

# %%
# Read the data into a list of strings.
def read_data(path, filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(path+filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(path, filename)
print('Dataset size: {:,} words'.format(len(vocabulary)))
# Out:
# Dataset size: 17,005,207 words

# %%
# Take a peak at the head
vocabulary[:20]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english']

# %% [markdown]
# Notice: None of the words are capitalized and there is no punctuation.
#
# Preprocessing is an art. It depends on your raw data and how you plan to use your final data. You might want to encode ngrams, instead of just splitting all items into unigrams.

# %% [markdown]
# -----
# Step 2: Build the dictionary
# -----

# %%
vocabulary_size = 50_000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)

# %% [markdown]
# Variable Legend
# ------
# data - list of codes (integers from 0 to vocabulary_size-1).
#     This is the original text but words are replaced by their codes
#
# count - map of words(strings) to count of occurrences
#
# dictionary - map of words(strings) to their codes(integers)
#
# reverse_dictionary - maps codes(integers) to words(strings)

# %%
del vocabulary # Reduce memory by getting rid of the "heavy" list of strings

# %%
data[:5] # An index of each word (as it appears in order) to its rank. Therefore we don't have reference the string
# Out:
# [5234, 3081, 12, 6, 195]

# %%
dictionary['the'] # word: rank
# Out:
# 1

# %%
reverse_dictionary[5234] # rank: word
# Out:
# 'anarchism'

# %%
print('Most common words:') 
print(*count[:5], sep="\n")
# Out:
# Most common words:
# ['UNK', 418391]
# ('the', 1061396)
# ('of', 593677)
# ('and', 416629)
# ('one', 411764)

# %%
print('Most least words:')
print(*count[-5:], sep="\n")
# Out:
# Most least words:
# ('codeword', 9)
# ('senussi', 9)
# ('unscr', 9)
# ('leonards', 9)
# ('hif', 9)

# %% [markdown]
# ----
# Step 3: Function to generate a training batch for the skip-gram model.
# -----

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer[:] = data[:span]
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, 
                               num_skips=2, 
                               skip_window=1)

# %%
# Example of self-supervised learning
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %% [markdown]
# ----
# Step 4: Build and train a skip-gram model.
# -----

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
import tensorflow.compat.v1 as v1

# %%
graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = v1.placeholder(tf.int32, shape=[batch_size])
    train_labels = v1.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = v1.constant(valid_examples, dtype=tf.int32)

    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            v1.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Compute the average NCE loss for the batch.
        # tf.nce_loss automatically draws a new sample of the negative labels each
        # time we evaluate the loss.
        # Explanation of the meaning of NCE loss:
        #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
        loss = tf.reduce_mean(
          tf.nn.nce_loss(weights=nce_weights,
                         biases=nce_biases,
                         labels=train_labels,
                         inputs=embed,
                         num_sampled=num_sampled,
                         num_classes=vocabulary_size))

        # Construct the SGD optimizer using a learning rate of 1.0.
        optimizer = v1.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(
          normalized_embeddings, valid_dataset)
        similarity = tf.matmul(
          valid_embeddings, normalized_embeddings, transpose_b=True)

        # Add variable initializer.
        init = v1.global_variables_initializer()

# %% [markdown]
# ----
# Step 5: Begin training.
# -----

# %%
num_steps = 100_001 #1 #2_001 #100_001

with v1.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2_000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 2_000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 4 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to '%s':" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
            print()
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  275.647705078125
# Nearest to 'united': dilbert, dynamite, ancestry, dianetic,
# Nearest to 'this': releasing, escorting, mensa, bowdoin,
# Nearest to 'his': clothing, mips, conjectural, large,
# Nearest to 'states': midshipman, examining, lightsaber, bernini,
# Nearest to 'american': grim, stockpiling, samplers, helsing,
# Nearest to 'not': wreck, helmet, amerindian, deutschlands,
# Nearest to 'into': forbidding, highest, rutherford, sale,
# Nearest to 'as': gorey, certificate, informally, malicious,
# Nearest to 'they': catamarans, salome, quotes, restarted,
# Nearest to 'an': por, capitalisation, evaluated, tc,
# Nearest to 'after': wmap, intricately, feasting, meer,
# Nearest to 'th': define, intervenes, emulator, implausible,
# Nearest to 'many': reorganisation, franks, pflp, moldovans,
# Nearest to 'no': snapper, thief, woolly, obligatory,
# Nearest to 'by': underwriting, paradoxes, archetypal, sieges,
# Nearest to 'war': develops, garbo, sociopolitical, messianic,
#
# Average loss at step  2000 :  112.1600756225586
# Nearest to 'united': two, name, son, money,
# Nearest to 'this': node, men, various, officially,
# Nearest to 'his': large, boom, the, always,
# Nearest to 'states': boom, during, babylon, persia,
# Nearest to 'american': grim, daniel, stockpiling, boom,
# Nearest to 'not': period, boom, bug, his,
# Nearest to 'into': highest, boom, campaign, shaken,
# Nearest to 'as': shall, boom, power, lose,
# Nearest to 'they': quotes, machine, information, checking,
# Nearest to 'an': boom, led, this, album,
# Nearest to 'after': down, boom, twelve, terms,
# Nearest to 'th': define, links, passage, curses,
# Nearest to 'many': law, order, tended, kane,
# Nearest to 'no': hitting, boom, pedro, bug,
# Nearest to 'by': talk, card, of, satellite,
# Nearest to 'war': heavy, building, boom, move,
#
# Average loss at step  4000 :  52.904081228256224
# Nearest to 'united': ursus, two, son, money,
# Nearest to 'this': the, node, length, men,
# Nearest to 'his': clothing, large, elisha, boom,
# Nearest to 'states': ursus, boom, babylon, during,
# Nearest to 'american': grim, stockpiling, daniel, arctos,
# Nearest to 'not': period, supporters, bug, boom,
# Nearest to 'into': uh, highest, campaign, successive,
# Nearest to 'as': shall, power, boom, is,
# Nearest to 'they': alison, concubines, depend, information,
# Nearest to 'an': thibetanus, boom, carried, three,
# Nearest to 'after': thibetanus, down, terms, ursinus,
# Nearest to 'th': define, ursus, curses, links,
# Nearest to 'many': law, deals, order, panda,
# Nearest to 'no': thief, messenger, divine, shown,
# Nearest to 'by': mammary, for, respect, ursus,
# Nearest to 'war': building, messianic, heavy, boom,
#
# Average loss at step  6000 :  34.153291324853896
# Nearest to 'united': bangor, ursus, var, two,
# Nearest to 'this': the, an, various, length,
# Nearest to 'his': bison, elisha, clothing, wct,
# Nearest to 'states': ursus, boom, tigris, persia,
# Nearest to 'american': bison, bangor, grim, stockpiling,
# Nearest to 'not': period, he, supporters, expansion,
# Nearest to 'into': uh, highest, campaign, successive,
# Nearest to 'as': shall, bison, power, is,
# Nearest to 'they': concubines, depend, tehran, alison,
# Nearest to 'an': bison, wct, three, avignon,
# Nearest to 'after': zero, bison, bangor, levi,
# Nearest to 'th': define, ursus, curses, zero,
# Nearest to 'many': syntax, wct, law, order,
# Nearest to 'no': shown, thief, messenger, divine,
# Nearest to 'by': for, bangor, mammary, of,
# Nearest to 'war': building, messianic, bangor, heavy,
#
# Average loss at step  8000 :  23.520503896951677
# Nearest to 'united': ancestry, bangor, ursus, var,
# Nearest to 'this': the, which, reality, nearby,
# Nearest to 'his': the, elisha, clothing, bison,
# Nearest to 'states': ursus, boom, persia, tigris,
# Nearest to 'american': stockpiling, bison, grim, bangor,
# Nearest to 'not': he, period, supermassive, ova,
# Nearest to 'into': uh, highest, successive, stalingrad,
# Nearest to 'as': and, in, wct, UNK,
# Nearest to 'they': concubines, tau, tehran, depend,
# Nearest to 'an': bison, wct, this, three,
# Nearest to 'after': levi, thibetanus, terms, intellectual,
# Nearest to 'th': define, wolf, curses, ursus,
# Nearest to 'many': syntax, reorganisation, the, wct,
# Nearest to 'no': shown, thief, hitting, divine,
# Nearest to 'by': and, for, mammary, of,
# Nearest to 'war': building, messianic, heavy, bangor,
#
# Average loss at step  10000 :  17.93284840774536
# Nearest to 'united': ancestry, bangor, ursus, var,
# Nearest to 'this': the, which, a, michelob,
# Nearest to 'his': the, bison, bangor, wct,
# Nearest to 'states': ursus, boom, persia, proposal,
# Nearest to 'american': stockpiling, grim, bison, bangor,
# Nearest to 'not': vickers, michelob, planetary, bottle,
# Nearest to 'into': uh, highest, distinguish, stalingrad,
# Nearest to 'as': banda, in, is, wct,
# Nearest to 'they': concubines, depend, tau, tehran,
# Nearest to 'an': this, three, bison, wct,
# Nearest to 'after': levi, banda, ks, thibetanus,
# Nearest to 'th': define, banda, curses, zero,
# Nearest to 'many': syntax, reorganisation, wct, tended,
# Nearest to 'no': shown, thief, volumes, banda,
# Nearest to 'by': and, for, UNK, in,
# Nearest to 'war': building, messianic, heavy, cert,
#
# Average loss at step  12000 :  13.869817278504371
# Nearest to 'united': dynamite, ancestry, pulau, bangor,
# Nearest to 'this': the, which, a, michelob,
# Nearest to 'his': the, its, bison, elisha,
# Nearest to 'states': ursus, boom, objective, persia,
# Nearest to 'american': stockpiling, two, bison, grim,
# Nearest to 'not': pulau, vickers, planetary, michelob,
# Nearest to 'into': uh, highest, from, distinguish,
# Nearest to 'as': in, banda, and, is,
# Nearest to 'they': concubines, depend, consumes, tehran,
# Nearest to 'an': the, this, three, a,
# Nearest to 'after': in, of, and, levi,
# Nearest to 'th': define, zero, curses, banda,
# Nearest to 'many': spindle, syntax, reorganisation, wct,
# Nearest to 'no': shown, volumes, thief, hitting,
# Nearest to 'by': and, UNK, for, in,
# Nearest to 'war': building, messianic, heavy, cert,
#
# Average loss at step  14000 :  11.548351448059082
# Nearest to 'united': dynamite, ancestry, pulau, bangor,
# Nearest to 'this': the, which, a, reality,
# Nearest to 'his': the, its, bison, their,
# Nearest to 'states': ursus, capitalist, persia, boom,
# Nearest to 'american': stockpiling, two, and, bison,
# Nearest to 'not': pulau, allotropes, vickers, planetary,
# Nearest to 'into': uh, from, highest, in,
# Nearest to 'as': in, banda, and, wct,
# Nearest to 'they': concubines, depend, consumes, tehran,
# Nearest to 'an': the, this, avignon, bison,
# Nearest to 'after': of, in, and, instruction,
# Nearest to 'th': define, six, banda, curses,
# Nearest to 'many': spindle, syntax, reorganisation, franks,
# Nearest to 'no': shown, med, volumes, thief,
# Nearest to 'by': and, UNK, in, bangor,
# Nearest to 'war': building, messianic, heavy, cert,
#
# Average loss at step  16000 :  9.74042395401001
# Nearest to 'united': dynamite, ancestry, pulau, bangor,
# Nearest to 'this': which, the, a, it,
# Nearest to 'his': the, its, their, bison,
# Nearest to 'states': ursus, capitalist, objective, boom,
# Nearest to 'american': stockpiling, bison, callithrix, two,
# Nearest to 'not': hubble, pulau, it, vickers,
# Nearest to 'into': uh, highest, from, successive,
# Nearest to 'as': banda, in, wct, boom,
# Nearest to 'they': concubines, depend, not, but,
# Nearest to 'an': the, three, this, bison,
# Nearest to 'after': of, in, wmap, and,
# Nearest to 'th': define, nine, banda, six,
# Nearest to 'many': spindle, syntax, reorganisation, pulau,
# Nearest to 'no': shown, med, volumes, thief,
# Nearest to 'by': and, in, UNK, for,
# Nearest to 'war': building, messianic, heavy, develops,
#
# Average loss at step  18000 :  7.946248438358307
# Nearest to 'united': dynamite, ancestry, pulau, powder,
# Nearest to 'this': the, which, it, a,
# Nearest to 'his': the, its, their, bison,
# Nearest to 'states': ursus, upanija, capitalist, objective,
# Nearest to 'american': stockpiling, bison, and, callithrix,
# Nearest to 'not': it, hubble, pulau, they,
# Nearest to 'into': uh, highest, from, successive,
# Nearest to 'as': banda, in, is, wct,
# Nearest to 'they': not, concubines, depend, but,
# Nearest to 'an': the, por, upanija, three,
# Nearest to 'after': wmap, of, in, for,
# Nearest to 'th': define, conspirators, nine, banda,
# Nearest to 'many': spindle, syntax, reorganisation, panda,
# Nearest to 'no': shown, med, volumes, thief,
# Nearest to 'by': and, from, in, for,
# Nearest to 'war': building, messianic, develops, cert,
#
# Average loss at step  20000 :  8.429555196523667
# Nearest to 'united': dynamite, ancestry, dilbert, dinar,
# Nearest to 'this': the, which, it, a,
# Nearest to 'his': the, its, their, bison,
# Nearest to 'states': securities, ursus, capitalist, upanija,
# Nearest to 'american': stockpiling, and, bison, callithrix,
# Nearest to 'not': they, pulau, vickers, hubble,
# Nearest to 'into': from, highest, uh, successive,
# Nearest to 'as': banda, is, dinar, microcebus,
# Nearest to 'they': not, concubines, chlorine, depend,
# Nearest to 'an': the, por, upanija, this,
# Nearest to 'after': dinar, for, wmap, in,
# Nearest to 'th': define, conspirators, nine, curses,
# Nearest to 'many': reorganisation, spindle, the, panda,
# Nearest to 'no': shown, med, volumes, thief,
# Nearest to 'by': in, and, for, was,
# Nearest to 'war': building, messianic, develops, cert,
#
# Average loss at step  22000 :  7.478136640548706
# Nearest to 'united': dynamite, ancestry, dilbert, dinar,
# Nearest to 'this': the, which, it, dinar,
# Nearest to 'his': the, their, its, bison,
# Nearest to 'states': ursus, securities, capitalist, upanija,
# Nearest to 'american': and, stockpiling, bison, callithrix,
# Nearest to 'not': pulau, they, vickers, michelob,
# Nearest to 'into': from, highest, uh, and,
# Nearest to 'as': is, banda, and, dinar,
# Nearest to 'they': not, concubines, chlorine, but,
# Nearest to 'an': the, por, upanija, avignon,
# Nearest to 'after': for, dinar, wmap, in,
# Nearest to 'th': define, conspirators, curses, nine,
# Nearest to 'many': reorganisation, panda, spindle, pulau,
# Nearest to 'no': shown, med, volumes, thief,
# Nearest to 'by': was, from, and, in,
# Nearest to 'war': develops, building, messianic, cert,
#
# Average loss at step  24000 :  6.696877770066261
# Nearest to 'united': dynamite, ancestry, dilbert, dinar,
# Nearest to 'this': the, which, it, dinar,
# Nearest to 'his': the, their, its, bison,
# Nearest to 'states': ursus, securities, capitalist, upanija,
# Nearest to 'american': stockpiling, and, bison, callithrix,
# Nearest to 'not': pulau, vickers, they, also,
# Nearest to 'into': from, highest, uh, oxide,
# Nearest to 'as': is, banda, dinar, wct,
# Nearest to 'they': not, concubines, there, but,
# Nearest to 'an': por, upanija, the, avignon,
# Nearest to 'after': for, dinar, in, four,
# Nearest to 'th': define, conspirators, nine, curses,
# Nearest to 'many': reorganisation, pulau, panda, spindle,
# Nearest to 'no': shown, med, volumes, thief,
# Nearest to 'by': was, in, from, as,
# Nearest to 'war': develops, messianic, building, cert,
#
# Average loss at step  26000 :  6.6100320687294
# Nearest to 'united': dynamite, ancestry, dilbert, dinar,
# Nearest to 'this': the, which, it, a,
# Nearest to 'his': the, their, its, bison,
# Nearest to 'states': ursus, securities, capitalist, upanija,
# Nearest to 'american': stockpiling, and, bison, callithrix,
# Nearest to 'not': also, they, pulau, it,
# Nearest to 'into': from, highest, forbidding, uh,
# Nearest to 'as': is, banda, and, in,
# Nearest to 'they': not, there, but, concubines,
# Nearest to 'an': the, por, upanija, avignon,
# Nearest to 'after': for, dinar, in, four,
# Nearest to 'th': define, conspirators, nine, curses,
# Nearest to 'many': some, reorganisation, symbolics, panda,
# Nearest to 'no': shown, med, thief, volumes,
# Nearest to 'by': was, in, with, from,
# Nearest to 'war': develops, building, messianic, cert,
#
# Average loss at step  28000 :  6.1622257241010665
# Nearest to 'united': dynamite, ancestry, dilbert, treating,
# Nearest to 'this': it, which, the, a,
# Nearest to 'his': their, the, its, bison,
# Nearest to 'states': securities, ursus, objective, capitalist,
# Nearest to 'american': stockpiling, and, bison, callithrix,
# Nearest to 'not': also, vickers, pulau, michelob,
# Nearest to 'into': from, highest, uh, forbidding,
# Nearest to 'as': banda, is, by, in,
# Nearest to 'they': there, not, but, it,
# Nearest to 'an': por, upanija, the, avignon,
# Nearest to 'after': in, for, dinar, during,
# Nearest to 'th': define, conspirators, nine, curses,
# Nearest to 'many': some, symbolics, panda, reorganisation,
# Nearest to 'no': shown, med, snapper, volumes,
# Nearest to 'by': was, in, from, be,
# Nearest to 'war': develops, building, messianic, cert,
#
# Average loss at step  30000 :  6.369338126391172
# Nearest to 'united': dynamite, ancestry, dilbert, treating,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, the, its, bison,
# Nearest to 'states': ursus, securities, objective, capitalist,
# Nearest to 'american': and, stockpiling, bison, callithrix,
# Nearest to 'not': they, also, it, michelob,
# Nearest to 'into': from, highest, uh, forbidding,
# Nearest to 'as': banda, cet, is, and,
# Nearest to 'they': there, not, he, but,
# Nearest to 'an': the, por, upanija, avignon,
# Nearest to 'after': for, dinar, during, diverge,
# Nearest to 'th': define, conspirators, nine, curses,
# Nearest to 'many': some, pulau, symbolics, panda,
# Nearest to 'no': shown, med, snapper, thief,
# Nearest to 'by': was, in, from, were,
# Nearest to 'war': building, develops, messianic, cert,
#
# Average loss at step  32000 :  6.19828227865696
# Nearest to 'united': dynamite, ancestry, dilbert, treating,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, the, its, bison,
# Nearest to 'states': fachhochschule, securities, ursus, objective,
# Nearest to 'american': and, stockpiling, bison, bangor,
# Nearest to 'not': it, also, they, to,
# Nearest to 'into': from, highest, in, forbidding,
# Nearest to 'as': banda, cet, is, microcebus,
# Nearest to 'they': there, he, not, it,
# Nearest to 'an': por, the, upanija, avignon,
# Nearest to 'after': for, during, dinar, diverge,
# Nearest to 'th': define, conspirators, curses, nine,
# Nearest to 'many': some, degli, pulau, other,
# Nearest to 'no': shown, med, snapper, thief,
# Nearest to 'by': in, was, from, with,
# Nearest to 'war': building, messianic, develops, cert,
#
# Average loss at step  34000 :  5.813378677368164
# Nearest to 'united': dynamite, ancestry, dilbert, treating,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, the, its, waxes,
# Nearest to 'states': fachhochschule, ursus, securities, objective,
# Nearest to 'american': stockpiling, and, bison, bangor,
# Nearest to 'not': they, to, it, also,
# Nearest to 'into': from, highest, forbidding, in,
# Nearest to 'as': banda, candide, for, cet,
# Nearest to 'they': there, he, not, who,
# Nearest to 'an': por, the, upanija, avignon,
# Nearest to 'after': for, during, in, dinar,
# Nearest to 'th': define, nine, conspirators, curses,
# Nearest to 'many': some, degli, pulau, other,
# Nearest to 'no': shown, med, snapper, thief,
# Nearest to 'by': was, from, be, iit,
# Nearest to 'war': building, messianic, develops, cert,
#
# Average loss at step  36000 :  5.684372143983841
# Nearest to 'united': dynamite, ancestry, dilbert, treating,
# Nearest to 'this': which, it, the, dinar,
# Nearest to 'his': their, the, its, waxes,
# Nearest to 'states': fachhochschule, securities, ursus, objective,
# Nearest to 'american': stockpiling, and, entire, covert,
# Nearest to 'not': it, they, also, to,
# Nearest to 'into': from, forbidding, highest, in,
# Nearest to 'as': candide, banda, cet, and,
# Nearest to 'they': he, there, not, it,
# Nearest to 'an': por, the, avignon, upanija,
# Nearest to 'after': during, for, in, dinar,
# Nearest to 'th': define, nine, conspirators, curses,
# Nearest to 'many': some, degli, other, these,
# Nearest to 'no': shown, med, snapper, thief,
# Nearest to 'by': was, from, be, in,
# Nearest to 'war': messianic, heavy, building, cert,
#
# Average loss at step  38000 :  5.664204632639885
# Nearest to 'united': dynamite, ancestry, dilbert, treating,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, its, the, eject,
# Nearest to 'states': fachhochschule, ursus, securities, upanija,
# Nearest to 'american': stockpiling, and, carbines, entire,
# Nearest to 'not': it, they, also, michelob,
# Nearest to 'into': from, highest, forbidding, oxide,
# Nearest to 'as': banda, candide, cet, microcebus,
# Nearest to 'they': he, there, not, it,
# Nearest to 'an': the, por, avignon, upanija,
# Nearest to 'after': during, for, in, diverge,
# Nearest to 'th': define, nine, conspirators, curses,
# Nearest to 'many': some, degli, these, other,
# Nearest to 'no': shown, med, snapper, thief,
# Nearest to 'by': was, be, in, from,
# Nearest to 'war': messianic, develops, cert, building,
#
# Average loss at step  40000 :  5.55797800385952
# Nearest to 'united': dynamite, ancestry, dilbert, treating,
# Nearest to 'this': which, it, the, doves,
# Nearest to 'his': their, its, the, doves,
# Nearest to 'states': fachhochschule, ursus, securities, pheasants,
# Nearest to 'american': stockpiling, and, carbines, bison,
# Nearest to 'not': it, they, to, also,
# Nearest to 'into': from, highest, forbidding, oxide,
# Nearest to 'as': candide, banda, microcebus, cet,
# Nearest to 'they': he, there, it, not,
# Nearest to 'an': por, the, upanija, avignon,
# Nearest to 'after': during, for, in, dinar,
# Nearest to 'th': define, nine, six, conspirators,
# Nearest to 'many': some, degli, these, other,
# Nearest to 'no': shown, med, menger, thief,
# Nearest to 'by': was, from, in, with,
# Nearest to 'war': messianic, develops, building, dingo,
#
# Average loss at step  42000 :  5.4658019539117815
# Nearest to 'united': dynamite, ancestry, dilbert, treating,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, its, the, eject,
# Nearest to 'states': fachhochschule, ursus, securities, pheasants,
# Nearest to 'american': stockpiling, and, carbines, bison,
# Nearest to 'not': it, they, to, michelob,
# Nearest to 'into': from, highest, forbidding, oxide,
# Nearest to 'as': candide, banda, by, cet,
# Nearest to 'they': he, there, not, it,
# Nearest to 'an': por, the, avignon, washing,
# Nearest to 'after': during, in, for, diverge,
# Nearest to 'th': nine, define, conspirators, curses,
# Nearest to 'many': some, these, degli, other,
# Nearest to 'no': shown, med, any, menger,
# Nearest to 'by': was, from, be, as,
# Nearest to 'war': messianic, develops, building, dingo,
#
# Average loss at step  44000 :  5.177133506894112
# Nearest to 'united': dynamite, ancestry, dilbert, treating,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, its, the, eject,
# Nearest to 'states': fachhochschule, ursus, securities, pheasants,
# Nearest to 'american': stockpiling, and, carbines, bangor,
# Nearest to 'not': it, to, they, also,
# Nearest to 'into': from, highest, forbidding, oxide,
# Nearest to 'as': banda, candide, cet, by,
# Nearest to 'they': he, there, it, not,
# Nearest to 'an': por, the, upanija, washing,
# Nearest to 'after': during, for, in, dinar,
# Nearest to 'th': define, nine, six, conspirators,
# Nearest to 'many': some, these, other, degli,
# Nearest to 'no': shown, med, any, it,
# Nearest to 'by': was, from, be, iit,
# Nearest to 'war': messianic, develops, heavy, building,
#
# Average loss at step  46000 :  5.3355187834501265
# Nearest to 'united': dynamite, ancestry, dilbert, treating,
# Nearest to 'this': it, which, the, doves,
# Nearest to 'his': their, its, the, eject,
# Nearest to 'states': fachhochschule, ursus, securities, pheasants,
# Nearest to 'american': and, stockpiling, carbines, entire,
# Nearest to 'not': they, it, also, michelob,
# Nearest to 'into': from, highest, forbidding, oxide,
# Nearest to 'as': banda, candide, cet, by,
# Nearest to 'they': he, there, it, not,
# Nearest to 'an': por, the, washing, avignon,
# Nearest to 'after': in, during, for, dinar,
# Nearest to 'th': define, nine, six, conspirators,
# Nearest to 'many': some, these, other, degli,
# Nearest to 'no': shown, med, any, snapper,
# Nearest to 'by': was, be, from, in,
# Nearest to 'war': messianic, develops, heavy, cert,
#
# Average loss at step  48000 :  5.242903676748276
# Nearest to 'united': dynamite, ancestry, dilbert, constituci,
# Nearest to 'this': it, which, the, that,
# Nearest to 'his': their, its, the, her,
# Nearest to 'states': fachhochschule, ursus, securities, pheasants,
# Nearest to 'american': and, stockpiling, carbines, entire,
# Nearest to 'not': it, to, they, also,
# Nearest to 'into': from, highest, oxide, forbidding,
# Nearest to 'as': by, banda, candide, cet,
# Nearest to 'they': he, there, it, not,
# Nearest to 'an': por, the, washing, avignon,
# Nearest to 'after': in, during, for, dinar,
# Nearest to 'th': define, nine, six, conspirators,
# Nearest to 'many': some, these, other, degli,
# Nearest to 'no': shown, any, med, snapper,
# Nearest to 'by': was, be, as, from,
# Nearest to 'war': messianic, develops, building, escalation,
#
# Average loss at step  50000 :  5.048835481524468
# Nearest to 'united': dynamite, ancestry, dilbert, constituci,
# Nearest to 'this': which, it, that, the,
# Nearest to 'his': their, its, the, her,
# Nearest to 'states': fachhochschule, ursus, securities, pheasants,
# Nearest to 'american': stockpiling, and, carbines, entire,
# Nearest to 'not': it, they, also, michelob,
# Nearest to 'into': from, highest, oxide, forbidding,
# Nearest to 'as': banda, by, cet, candide,
# Nearest to 'they': he, there, it, not,
# Nearest to 'an': por, washing, the, avignon,
# Nearest to 'after': during, in, four, dinar,
# Nearest to 'th': define, curses, emulator, conspirators,
# Nearest to 'many': some, these, other, degli,
# Nearest to 'no': shown, any, snapper, med,
# Nearest to 'by': was, be, with, from,
# Nearest to 'war': messianic, develops, building, escalation,
#
# Average loss at step  52000 :  5.261038280725479
# Nearest to 'united': dynamite, dilbert, ancestry, constituci,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, its, the, her,
# Nearest to 'states': fachhochschule, ursus, pheasants, securities,
# Nearest to 'american': and, stockpiling, carbines, bangor,
# Nearest to 'not': they, it, also, to,
# Nearest to 'into': from, highest, oxide, forbidding,
# Nearest to 'as': by, banda, cet, candide,
# Nearest to 'they': he, there, it, not,
# Nearest to 'an': por, avignon, the, washing,
# Nearest to 'after': during, in, for, dinar,
# Nearest to 'th': define, nine, curses, conspirators,
# Nearest to 'many': some, these, other, degli,
# Nearest to 'no': shown, snapper, any, med,
# Nearest to 'by': be, was, as, with,
# Nearest to 'war': messianic, building, heavy, dingo,
#
# Average loss at step  54000 :  5.152845226109028
# Nearest to 'united': dynamite, dilbert, ancestry, constituci,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, its, the, her,
# Nearest to 'states': fachhochschule, ursus, pheasants, securities,
# Nearest to 'american': and, carbines, stockpiling, bangor,
# Nearest to 'not': they, it, to, also,
# Nearest to 'into': from, highest, forbidding, to,
# Nearest to 'as': banda, cet, by, candide,
# Nearest to 'they': he, there, not, it,
# Nearest to 'an': por, the, washing, avignon,
# Nearest to 'after': during, in, four, at,
# Nearest to 'th': define, curses, emulator, conspirators,
# Nearest to 'many': some, these, other, several,
# Nearest to 'no': shown, snapper, any, med,
# Nearest to 'by': be, was, as, from,
# Nearest to 'war': messianic, building, escalation, dingo,
#
# Average loss at step  56000 :  5.12866556584835
# Nearest to 'united': dynamite, dilbert, ancestry, constituci,
# Nearest to 'this': which, it, that, the,
# Nearest to 'his': their, its, the, her,
# Nearest to 'states': fachhochschule, ursus, pheasants, securities,
# Nearest to 'american': and, carbines, stockpiling, bangor,
# Nearest to 'not': they, it, also, to,
# Nearest to 'into': from, highest, successive, oxide,
# Nearest to 'as': banda, by, candide, cet,
# Nearest to 'they': he, there, it, we,
# Nearest to 'an': por, washing, avignon, the,
# Nearest to 'after': during, in, four, dinar,
# Nearest to 'th': define, emulator, nine, curses,
# Nearest to 'many': some, these, other, several,
# Nearest to 'no': shown, snapper, any, med,
# Nearest to 'by': be, was, with, as,
# Nearest to 'war': messianic, building, escalation, heavy,
#
# Average loss at step  58000 :  5.092930722355843
# Nearest to 'united': dilbert, dynamite, ancestry, treating,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, its, the, her,
# Nearest to 'states': fachhochschule, ursus, pheasants, securities,
# Nearest to 'american': and, carbines, stockpiling, british,
# Nearest to 'not': they, it, to, michelob,
# Nearest to 'into': from, highest, to, blah,
# Nearest to 'as': banda, by, cet, candide,
# Nearest to 'they': he, there, we, not,
# Nearest to 'an': the, por, washing, avignon,
# Nearest to 'after': during, in, four, for,
# Nearest to 'th': define, emulator, curses, conspirators,
# Nearest to 'many': some, these, other, several,
# Nearest to 'no': shown, snapper, any, med,
# Nearest to 'by': be, with, was, as,
# Nearest to 'war': messianic, building, escalation, heavy,
#
# Average loss at step  60000 :  5.030476136088371
# Nearest to 'united': dilbert, dynamite, ancestry, constituci,
# Nearest to 'this': which, it, that, the,
# Nearest to 'his': their, its, the, her,
# Nearest to 'states': fachhochschule, ursus, pheasants, fullmetal,
# Nearest to 'american': and, carbines, stockpiling, british,
# Nearest to 'not': it, they, to, also,
# Nearest to 'into': from, to, highest, blah,
# Nearest to 'as': banda, candide, by, cet,
# Nearest to 'they': he, there, we, it,
# Nearest to 'an': the, por, washing, avignon,
# Nearest to 'after': during, in, for, at,
# Nearest to 'th': define, emulator, curses, conspirators,
# Nearest to 'many': some, these, other, several,
# Nearest to 'no': shown, any, snapper, med,
# Nearest to 'by': with, be, was, iit,
# Nearest to 'war': building, messianic, escalation, dingo,
#
# Average loss at step  62000 :  4.932201505661011
# Nearest to 'united': dilbert, dynamite, ancestry, constituci,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, its, the, her,
# Nearest to 'states': fachhochschule, ursus, pheasants, securities,
# Nearest to 'american': carbines, and, british, bangor,
# Nearest to 'not': it, they, also, to,
# Nearest to 'into': from, highest, to, during,
# Nearest to 'as': banda, by, candide, cet,
# Nearest to 'they': he, there, we, it,
# Nearest to 'an': por, washing, avignon, upanija,
# Nearest to 'after': during, in, for, four,
# Nearest to 'th': define, emulator, curses, six,
# Nearest to 'many': some, these, other, several,
# Nearest to 'no': shown, any, snapper, med,
# Nearest to 'by': with, was, be, as,
# Nearest to 'war': building, escalation, dingo, messianic,
#
# Average loss at step  64000 :  4.973878635883331
# Nearest to 'united': dilbert, ancestry, dynamite, constituci,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, its, the, her,
# Nearest to 'states': fachhochschule, ursus, pheasants, fullmetal,
# Nearest to 'american': carbines, and, british, stockpiling,
# Nearest to 'not': they, it, also, michelob,
# Nearest to 'into': from, highest, blah, during,
# Nearest to 'as': banda, cet, candide, doves,
# Nearest to 'they': he, there, we, not,
# Nearest to 'an': por, washing, avignon, the,
# Nearest to 'after': during, for, in, at,
# Nearest to 'th': define, emulator, curses, nine,
# Nearest to 'many': some, these, several, all,
# Nearest to 'no': any, shown, snapper, a,
# Nearest to 'by': with, be, was, vert,
# Nearest to 'war': building, messianic, dingo, escalation,
#
# Average loss at step  66000 :  4.838178859949112
# Nearest to 'united': dilbert, ancestry, dynamite, constituci,
# Nearest to 'this': which, it, that, the,
# Nearest to 'his': their, its, her, the,
# Nearest to 'states': fachhochschule, fullmetal, nations, ursus,
# Nearest to 'american': carbines, british, and, bangor,
# Nearest to 'not': they, it, to, also,
# Nearest to 'into': from, highest, to, after,
# Nearest to 'as': banda, cet, doves, candide,
# Nearest to 'they': there, he, we, it,
# Nearest to 'an': washing, por, avignon, eurovision,
# Nearest to 'after': during, in, at, for,
# Nearest to 'th': define, nine, emulator, curses,
# Nearest to 'many': some, these, several, other,
# Nearest to 'no': shown, any, snapper, med,
# Nearest to 'by': was, be, with, as,
# Nearest to 'war': building, escalation, messianic, dingo,
#
# Average loss at step  68000 :  4.691682746171951
# Nearest to 'united': dilbert, ancestry, dynamite, constituci,
# Nearest to 'this': which, it, that, the,
# Nearest to 'his': their, its, her, the,
# Nearest to 'states': fachhochschule, nations, ursus, fullmetal,
# Nearest to 'american': carbines, british, and, bangor,
# Nearest to 'not': they, it, leibniz, usually,
# Nearest to 'into': from, to, highest, oxide,
# Nearest to 'as': banda, candide, cet, microcebus,
# Nearest to 'they': there, he, we, it,
# Nearest to 'an': por, washing, avignon, sadistic,
# Nearest to 'after': during, in, four, for,
# Nearest to 'th': emulator, define, nine, zero,
# Nearest to 'many': some, these, several, other,
# Nearest to 'no': any, shown, snapper, med,
# Nearest to 'by': was, with, be, vert,
# Nearest to 'war': building, dingo, escalation, messianic,
#
# Average loss at step  70000 :  4.867609629154205
# Nearest to 'united': dilbert, ancestry, dynamite, constituci,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, its, her, the,
# Nearest to 'states': fachhochschule, ursus, nations, pheasants,
# Nearest to 'american': carbines, british, english, and,
# Nearest to 'not': they, it, also, usually,
# Nearest to 'into': from, highest, oxide, blah,
# Nearest to 'as': banda, by, candide, cet,
# Nearest to 'they': there, he, we, you,
# Nearest to 'an': por, washing, avignon, the,
# Nearest to 'after': during, for, under, before,
# Nearest to 'th': nine, define, emulator, curses,
# Nearest to 'many': some, these, several, other,
# Nearest to 'no': shown, any, snapper, med,
# Nearest to 'by': was, be, as, with,
# Nearest to 'war': building, escalation, dingo, messianic,
#
# Average loss at step  72000 :  4.784970384597778
# Nearest to 'united': dilbert, ancestry, dynamite, constituci,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, its, her, the,
# Nearest to 'states': fachhochschule, nations, ursus, fullmetal,
# Nearest to 'american': carbines, english, british, stockpiling,
# Nearest to 'not': they, it, also, usually,
# Nearest to 'into': from, highest, oxide, to,
# Nearest to 'as': banda, candide, by, microcebus,
# Nearest to 'they': there, he, we, you,
# Nearest to 'an': por, avignon, washing, calculators,
# Nearest to 'after': during, in, at, when,
# Nearest to 'th': emulator, define, curses, nine,
# Nearest to 'many': some, these, several, other,
# Nearest to 'no': shown, any, snapper, med,
# Nearest to 'by': be, was, as, from,
# Nearest to 'war': building, dingo, escalation, messianic,
#
# Average loss at step  74000 :  4.84447692000866
# Nearest to 'united': dilbert, ancestry, dynamite, constituci,
# Nearest to 'this': which, it, the, dinar,
# Nearest to 'his': their, its, her, the,
# Nearest to 'states': fachhochschule, nations, ursus, fullmetal,
# Nearest to 'american': carbines, british, english, stockpiling,
# Nearest to 'not': they, it, also, usually,
# Nearest to 'into': from, to, highest, oxide,
# Nearest to 'as': banda, candide, cet, pheasants,
# Nearest to 'they': there, he, we, you,
# Nearest to 'an': por, washing, avignon, calculators,
# Nearest to 'after': during, when, six, at,
# Nearest to 'th': nine, define, emulator, curses,
# Nearest to 'many': some, these, several, all,
# Nearest to 'no': any, shown, snapper, med,
# Nearest to 'by': be, was, from, with,
# Nearest to 'war': building, escalation, dingo, messianic,
#
# Average loss at step  76000 :  4.77631800365448
# Nearest to 'united': dilbert, dynamite, ancestry, constituci,
# Nearest to 'this': which, it, the, dinar,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': fachhochschule, nations, ursus, fullmetal,
# Nearest to 'american': carbines, british, english, and,
# Nearest to 'not': they, it, usually, also,
# Nearest to 'into': from, to, oxide, after,
# Nearest to 'as': banda, candide, cet, pheasants,
# Nearest to 'they': there, he, we, you,
# Nearest to 'an': por, washing, the, avignon,
# Nearest to 'after': during, when, at, before,
# Nearest to 'th': nine, zero, define, emulator,
# Nearest to 'many': some, these, several, other,
# Nearest to 'no': any, shown, snapper, a,
# Nearest to 'by': was, be, from, as,
# Nearest to 'war': building, escalation, dingo, messianic,
#
# Average loss at step  78000 :  4.833709332704544
# Nearest to 'united': dilbert, dynamite, ancestry, constituci,
# Nearest to 'this': which, it, the, dinar,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': nations, fachhochschule, ursus, congruences,
# Nearest to 'american': british, carbines, english, and,
# Nearest to 'not': they, it, usually, also,
# Nearest to 'into': from, oxide, after, during,
# Nearest to 'as': banda, by, candide, cet,
# Nearest to 'they': there, he, we, you,
# Nearest to 'an': por, washing, avignon, the,
# Nearest to 'after': during, when, six, four,
# Nearest to 'th': nine, zero, curses, emulator,
# Nearest to 'many': some, these, several, other,
# Nearest to 'no': any, shown, snapper, med,
# Nearest to 'by': was, be, from, as,
# Nearest to 'war': building, dingo, escalation, messianic,
#
# Average loss at step  80000 :  4.807368497014045
# Nearest to 'united': dilbert, dynamite, ancestry, constituci,
# Nearest to 'this': which, it, the, neutronic,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': nations, fachhochschule, ursus, fullmetal,
# Nearest to 'american': british, carbines, english, and,
# Nearest to 'not': it, they, usually, often,
# Nearest to 'into': from, oxide, through, blah,
# Nearest to 'as': banda, cet, by, dinar,
# Nearest to 'they': there, he, we, you,
# Nearest to 'an': por, washing, the, avignon,
# Nearest to 'after': during, when, four, before,
# Nearest to 'th': nine, zero, curses, define,
# Nearest to 'many': some, these, several, all,
# Nearest to 'no': any, shown, snapper, med,
# Nearest to 'by': was, be, with, as,
# Nearest to 'war': building, dingo, escalation, cert,
#
# Average loss at step  82000 :  4.64602743601799
# Nearest to 'united': dilbert, dynamite, ancestry, constituci,
# Nearest to 'this': which, it, the, neutronic,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': nations, fachhochschule, ursus, fullmetal,
# Nearest to 'american': british, english, carbines, and,
# Nearest to 'not': they, it, usually, michelob,
# Nearest to 'into': from, oxide, through, blah,
# Nearest to 'as': banda, cet, dinar, sanjo,
# Nearest to 'they': he, there, we, you,
# Nearest to 'an': por, washing, avignon, calculators,
# Nearest to 'after': during, when, before, under,
# Nearest to 'th': nine, six, curses, seven,
# Nearest to 'many': some, these, several, other,
# Nearest to 'no': any, shown, snapper, menger,
# Nearest to 'by': be, was, with, sanjo,
# Nearest to 'war': escalation, building, dingo, cert,
#
# Average loss at step  84000 :  4.611292516112328
# Nearest to 'united': dilbert, ancestry, dynamite, constituci,
# Nearest to 'this': which, it, the, neutronic,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': nations, fachhochschule, ursus, congruences,
# Nearest to 'american': british, english, and, carbines,
# Nearest to 'not': they, it, usually, often,
# Nearest to 'into': from, in, to, through,
# Nearest to 'as': banda, cet, dinar, pheasants,
# Nearest to 'they': he, there, we, you,
# Nearest to 'an': por, washing, avignon, calculators,
# Nearest to 'after': during, when, before, six,
# Nearest to 'th': nine, six, curses, emulator,
# Nearest to 'many': some, these, several, other,
# Nearest to 'no': any, shown, snapper, nine,
# Nearest to 'by': be, was, sanjo, with,
# Nearest to 'war': dingo, escalation, building, cert,
#
# Average loss at step  86000 :  4.701603833079338
# Nearest to 'united': dilbert, dynamite, ancestry, constituci,
# Nearest to 'this': which, it, the, neutronic,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': nations, fachhochschule, ursus, fullmetal,
# Nearest to 'american': british, english, carbines, and,
# Nearest to 'not': they, it, to, often,
# Nearest to 'into': from, through, oxide, in,
# Nearest to 'as': banda, cet, interact, candide,
# Nearest to 'they': he, there, we, you,
# Nearest to 'an': por, washing, avignon, calculators,
# Nearest to 'after': during, before, when, following,
# Nearest to 'th': nine, six, curses, seven,
# Nearest to 'many': some, these, several, all,
# Nearest to 'no': any, shown, snapper, a,
# Nearest to 'by': be, was, with, sanjo,
# Nearest to 'war': escalation, dingo, building, cert,
#
# Average loss at step  88000 :  4.683473373651505
# Nearest to 'united': dilbert, ancestry, dynamite, constituci,
# Nearest to 'this': which, it, the, neutronic,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': nations, fachhochschule, ursus, fullmetal,
# Nearest to 'american': british, english, and, carbines,
# Nearest to 'not': they, it, usually, to,
# Nearest to 'into': from, through, in, oxide,
# Nearest to 'as': banda, cet, pheasants, dinar,
# Nearest to 'they': he, there, we, you,
# Nearest to 'an': por, washing, avignon, calculators,
# Nearest to 'after': during, before, when, in,
# Nearest to 'th': curses, emulator, nine, define,
# Nearest to 'many': some, these, several, all,
# Nearest to 'no': any, shown, a, snapper,
# Nearest to 'by': with, be, was, sanjo,
# Nearest to 'war': building, escalation, dingo, cert,
#
# Average loss at step  90000 :  4.650809827327728
# Nearest to 'united': dilbert, dynamite, ancestry, constituci,
# Nearest to 'this': which, it, the, neutronic,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': nations, fachhochschule, ursus, fullmetal,
# Nearest to 'american': british, english, and, carbines,
# Nearest to 'not': they, it, to, there,
# Nearest to 'into': from, through, in, oxide,
# Nearest to 'as': banda, cet, pheasants, interact,
# Nearest to 'they': he, there, we, you,
# Nearest to 'an': por, avignon, washing, intake,
# Nearest to 'after': during, before, when, four,
# Nearest to 'th': curses, nine, emulator, define,
# Nearest to 'many': some, these, several, all,
# Nearest to 'no': any, shown, a, snapper,
# Nearest to 'by': be, with, was, sanjo,
# Nearest to 'war': building, dingo, escalation, cert,
#
# Average loss at step  92000 :  4.667160255074501
# Nearest to 'united': dilbert, dynamite, ancestry, grouse,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': nations, fullmetal, congruences, fachhochschule,
# Nearest to 'american': british, english, and, carbines,
# Nearest to 'not': they, it, usually, there,
# Nearest to 'into': from, through, oxide, to,
# Nearest to 'as': banda, cet, pheasants, interact,
# Nearest to 'they': he, there, we, you,
# Nearest to 'an': por, avignon, washing, the,
# Nearest to 'after': during, before, when, seven,
# Nearest to 'th': curses, six, nine, zero,
# Nearest to 'many': some, these, several, other,
# Nearest to 'no': any, shown, snapper, a,
# Nearest to 'by': be, sanjo, with, was,
# Nearest to 'war': escalation, building, dingo, cert,
#
# Average loss at step  94000 :  4.6894490448832515
# Nearest to 'united': dilbert, dynamite, ancestry, constituci,
# Nearest to 'this': which, it, that, the,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': nations, fachhochschule, fullmetal, ursus,
# Nearest to 'american': british, english, carbines, and,
# Nearest to 'not': they, it, usually, there,
# Nearest to 'into': from, through, oxide, blah,
# Nearest to 'as': banda, cet, interact, pheasants,
# Nearest to 'they': he, we, there, you,
# Nearest to 'an': por, washing, avignon, calculators,
# Nearest to 'after': during, before, when, five,
# Nearest to 'th': curses, zero, emulator, nine,
# Nearest to 'many': some, these, several, other,
# Nearest to 'no': any, shown, snapper, nine,
# Nearest to 'by': was, sanjo, with, be,
# Nearest to 'war': escalation, building, dingo, garbo,
#
# Average loss at step  96000 :  4.618062467217445
# Nearest to 'united': dilbert, dynamite, ancestry, constituci,
# Nearest to 'this': which, it, the, neutronic,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': nations, fachhochschule, ursus, fullmetal,
# Nearest to 'american': british, english, carbines, french,
# Nearest to 'not': they, it, usually, there,
# Nearest to 'into': from, through, oxide, blah,
# Nearest to 'as': banda, cet, pheasants, sanjo,
# Nearest to 'they': he, there, we, you,
# Nearest to 'an': por, the, washing, avignon,
# Nearest to 'after': during, before, when, under,
# Nearest to 'th': curses, zero, six, nine,
# Nearest to 'many': some, these, several, other,
# Nearest to 'no': any, shown, snapper, nine,
# Nearest to 'by': sanjo, was, with, be,
# Nearest to 'war': building, escalation, dingo, garbo,
#
# Average loss at step  98000 :  4.639223980665207
# Nearest to 'united': dilbert, dynamite, ancestry, constituci,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': nations, fachhochschule, ursus, fullmetal,
# Nearest to 'american': british, english, carbines, german,
# Nearest to 'not': they, it, usually, there,
# Nearest to 'into': from, through, oxide, blah,
# Nearest to 'as': banda, cet, pheasants, sanjo,
# Nearest to 'they': he, we, there, you,
# Nearest to 'an': por, washing, avignon, the,
# Nearest to 'after': during, before, when, following,
# Nearest to 'th': nine, curses, zero, seven,
# Nearest to 'many': some, several, these, other,
# Nearest to 'no': any, shown, a, snapper,
# Nearest to 'by': with, sanjo, be, was,
# Nearest to 'war': escalation, building, dingo, garbo,
#
# Average loss at step  100000 :  4.636439339995384
# Nearest to 'united': dilbert, ancestry, dynamite, constituci,
# Nearest to 'this': which, it, the, that,
# Nearest to 'his': their, her, its, the,
# Nearest to 'states': nations, fachhochschule, fullmetal, congruences,
# Nearest to 'american': british, english, carbines, german,
# Nearest to 'not': they, it, usually, there,
# Nearest to 'into': from, through, oxide, blah,
# Nearest to 'as': banda, cet, stadtbahn, pheasants,
# Nearest to 'they': he, we, there, you,
# Nearest to 'an': por, washing, avignon, sadistic,
# Nearest to 'after': during, before, when, following,
# Nearest to 'th': nine, zero, curses, seven,
# Nearest to 'many': some, several, these, other,
# Nearest to 'no': any, shown, snapper, a,
# Nearest to 'by': sanjo, with, be, was,
# Nearest to 'war': escalation, building, dingo, garbo,

# %% [markdown]
# <center><img src="../images/watiing.jpg" width="700"/></center>

# %% [markdown]
# -----
# Step 6: Visualize the embeddings.
# ----
#
# We'll use t-sne.
#
# [t-sne](https://lvdmaaten.github.io/tsne/) is a cool way to visualize of high-dimensional datasets by reducing the number dimensions.

# %%
tsne = TSNE(perplexity=30, 
            n_components=2, 
            init='pca', 
            n_iter=5_000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]

n_words_to_visualize = 40

for i, label in enumerate(labels[:n_words_to_visualize]):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %% [markdown]
# ----
# Reflective Questions
# ----
#
# What do you see?
#
# How would you describe the relationships?

# %%
# The words are close to each other because they are similar in meaning.

# %% [markdown]
# ------
#
# Let's render and save more samples.

# %%
def plot_with_labels(low_dim_embs, labels, filename='./images/tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 5
#       3 low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
#       4 labels = [reverse_dictionary[i] for i in range(plot_only)]
# ----> 5 plot_with_labels(low_dim_embs, labels)
#
# Cell In[29], line 14, in plot_with_labels(low_dim_embs, labels, filename)
#       6     plt.scatter(x, y)
#       7     plt.annotate(label,
#       8                  xy=(x, y),
#       9                  xytext=(5, 2),
#      10                  textcoords='offset points',
#      11                  ha='right',
#      12                  va='bottom')
# ---> 14 plt.savefig(filename)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:1119, in savefig(*args, **kwargs)
#    1116 fig = gcf()
#    1117 # savefig default implementation has no return, so mypy is unhappy
#    1118 # presumably this is here because subclasses can return?
# -> 1119 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1120 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1121 return res
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/backend_bases.py:2187, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2183 try:
#    2184     # _get_renderer may change the figure dpi (as vector formats
#    2185     # force the figure dpi to 72), so we need to set it again here.
#    2186     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2187         result = print_method(
#    2188             filename,
#    2189             facecolor=facecolor,
#    2190             edgecolor=edgecolor,
#    2191             orientation=orientation,
#    2192             bbox_inches_restore=_bbox_inches_restore,
#    2193             **kwargs)
#    2194 finally:
#    2195     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/PIL/Image.py:2436, in Image.save(self, fp, format, **params)
#    2434         fp = builtins.open(filename, "r+b")
#    2435     else:
# -> 2436         fp = builtins.open(filename, "w+b")
#    2438 try:
#    2439     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/tsne.png'

# %% [markdown]
# Embedding Visualizer
# ------
# Check out a better version: [Embedding projector](https://www.tensorflow.org/tensorboard/tensorboard_projector_plugin)
